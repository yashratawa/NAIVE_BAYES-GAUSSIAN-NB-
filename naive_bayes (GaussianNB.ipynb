# %%
import pandas as pd

# %%
a = pd.read_csv('train.csv')
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.drop(['Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis = 'columns', inplace = True)
a
# Out:
#      PassengerId  Survived  Pclass     Sex   Age     Fare
# 0              1         0       3    male  22.0   7.2500
# 1              2         1       1  female  38.0  71.2833
# 2              3         1       3  female  26.0   7.9250
# 3              4         1       1  female  35.0  53.1000
# 4              5         0       3    male  35.0   8.0500
# ..           ...       ...     ...     ...   ...      ...
# 886          887         0       2    male  27.0  13.0000
# 887          888         1       1  female  19.0  30.0000
# 888          889         0       3  female   NaN  23.4500
# 889          890         1       1    male  26.0  30.0000
# 890          891         0       3    male  32.0   7.7500
#
# [891 rows x 6 columns]

# %%
dummy = pd.get_dummies(a.Sex)
dummy
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
x = a.drop(['Survived'], axis = 'columns')
x.head()
# Out:
#    PassengerId  Pclass     Sex   Age     Fare
# 0            1       3    male  22.0   7.2500
# 1            2       1  female  38.0  71.2833
# 2            3       3  female  26.0   7.9250
# 3            4       1  female  35.0  53.1000
# 4            5       3    male  35.0   8.0500

# %%
y = a.Survived
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
newx = pd.concat([x,dummy], axis = 'columns')
newx.head()
# Out:
#    PassengerId  Pclass     Sex   Age     Fare  female  male
# 0            1       3    male  22.0   7.2500       0     1
# 1            2       1  female  38.0  71.2833       1     0
# 2            3       3  female  26.0   7.9250       1     0
# 3            4       1  female  35.0  53.1000       1     0
# 4            5       3    male  35.0   8.0500       0     1

# %%
newx.drop(['Sex'], axis = 'columns', inplace = True)
newx.head()
# Out:
#    PassengerId  Pclass   Age     Fare  female  male
# 0            1       3  22.0   7.2500       0     1
# 1            2       1  38.0  71.2833       1     0
# 2            3       3  26.0   7.9250       1     0
# 3            4       1  35.0  53.1000       1     0
# 4            5       3  35.0   8.0500       0     1

# %%
newx.columns[newx.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
newx.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
mean = newx.Age.mean()
mean
# Out:
# 29.69911764705882

# %%
newx.Age = newx.Age.fillna(30)

# %%
newx.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    30.0
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_tr,x_ts,y_tr,y_ts = train_test_split(newx,y, test_size = 0.7)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model.fit(x_tr,y_tr)
# Out:
# GaussianNB()

# %%
model.score(x_ts,y_ts)
# Out:
# 0.7948717948717948

# %%
y_ts[:10]
# Out:
# 654    0
# 728    0
# 56     1
# 598    0
# 503    0
# 353    0
# 210    0
# 872    0
# 4      0
# 484    1
# Name: Survived, dtype: int64

# %%
e = model.predict(x_ts.head())
e[:5]
# Out:
# array([1, 0, 1, 0, 1], dtype=int64)

# %%
import matplotlib.pyplot as plt

# %%
z={'srvived': e, "Age" : x_ts.Age, 'female' : x_ts.female, 'male' : x_ts.male, 'Passenger Id' : x_ts.PassengerId}
b=pd.DataFrame(z)
b
#this shows that according to the prediction, only female passengers survived...(1=suvived,
#                                                                                0= not survived)
# Out:
#      srvived   Age  female  male  Passenger Id
# 654        1  18.0       1     0           655
# 728        0  25.0       0     1           729
# 56         1  21.0       1     0            57
# 598        0  30.0       0     1           599
# 503        1  37.0       1     0           504
# ..       ...   ...     ...   ...           ...
# 845        0  42.0       0     1           846
# 694        0  60.0       0     1           695
# 268        1  58.0       1     0           269
# 542        1  11.0       1     0           543
# 308        0  30.0       0     1           309
#
# [624 rows x 5 columns]
